# %%
import sys
sys.path.append('../')

from prop.tasks import narmax, santa_fe
import matplotlib.pyplot as plt
import numpy as np

# %%
u, narma10 = narmax(order=10)
_, narma20 = narmax(order=20)
_, narma30 = narmax(order=30)
_, narma40 = narmax(order=40)
_, narma50 = narmax(order=50)
narmas = [narma10, narma20, narma30]
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/dgca_tasks/lib/python3.10/site-packages/reservoirpy/datasets/_chaos.py:623: RuntimeWarning: overflow encountered in multiply
#   + a2 * y[t] * np.sum(y[t - order : t])

# %%
import matplotlib.cm as cm

plt.figure(figsize=(30, 6))

cmap = plt.get_cmap("Set1")  # Change to another colormap if desired

i = 10
for idx, y in enumerate(narmas):
    x = np.linspace(0, 300, 300)
    plt.plot(x, y[0, 1700:], label=i, color=cmap(idx % 10))  # Cycle through colors
    i += 10

plt.xlabel("t")
plt.ylabel("target")
plt.title("NARMA-N", fontsize=20)
plt.legend()
plt.savefig("narma_bg.pdf", format="pdf", bbox_inches="tight")
plt.show()

# %%
_, y = santa_fe()

plt.figure(figsize=(30, 6))

cmap = plt.get_cmap("Set1")  # Change to another colormap if desired

x = np.linspace(0, y.shape[-1], y.shape[-1])
plt.plot(x, y[0, :], color=cmap(idx % 10))  # Cycle through colors

plt.xlabel("t")
plt.ylabel("target")
plt.title("Santa Fe Laser", fontsize=20)
plt.legend()
plt.savefig("santafe_bg.pdf", format="pdf", bbox_inches="tight")
plt.show()
# Out:
# /var/folders/bd/sb4c0kpn6c97z9hkd8vmh2gm0000gn/T/ipykernel_5336/1400037528.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
